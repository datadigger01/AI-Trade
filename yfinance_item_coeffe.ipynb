# %% [markdown]
# <a href="https://colab.research.google.com/github/datadigger01/AI-Trade/blob/main/yfinance_item_coeffe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import yfinance as yf
import datetime
from datetime import date, timedelta
import matplotlib.pyplot as plt

# %%
#symbol = 'BTC-USD'
#period = '1mo'
#price_data = yf.download(symbol, period=period)

symbol = 'KC=F'
period = '30y'
price_data = yf.download(symbol, period=period)
price_data
# Out:
# /tmp/ipython-input-366308539.py:7: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   price_data = yf.download(symbol, period=period)
# [*********************100%***********************]  1 of 1 completed
# Price            Close        High         Low        Open Volume
# Ticker            KC=F        KC=F        KC=F        KC=F   KC=F
# Date
# 2000-01-03  116.500000  124.000000  116.099998  124.000000   6640
# 2000-01-04  116.250000  120.500000  115.750000  116.500000   5492
# 2000-01-05  118.599998  121.000000  115.000000  115.000000   6165
# 2000-01-06  116.849998  121.400002  116.500000  119.000000   5094
# 2000-01-07  114.150002  117.750000  113.800003  117.750000   6855
# ...                ...         ...         ...         ...    ...
# 2025-09-12  410.649994  410.649994  410.649994  410.649994      0
# 2025-09-15  432.350006  425.149994  422.899994  422.899994     24
# 2025-09-16  422.250000  431.299988  422.000000  428.700012     20
# ...

# %%
price_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1259 entries, 2020-09-18 to 2025-09-18
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   (Close, KC=F)   1259 non-null   float64
#  1   (High, KC=F)    1259 non-null   float64
#  2   (Low, KC=F)     1259 non-null   float64
#  3   (Open, KC=F)    1259 non-null   float64
#  4   (Volume, KC=F)  1259 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 59.0 KB

# %%
plt.figure(figsize=(12, 6))
plt.plot(price_data.index, price_data[('Close', 'KC=F')], label='Coffee Price')
plt.title('Close Price Over Time')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.grid(True, alpha=0.3)
plt.legend()
plt.tight_layout()
plt.show()
